# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from shapely.geometry import Point, Polygon
import pyproj
import re

# %% [markdown]
# # point transformation

# %%
import pyproj

print(pyproj.__version__)  # 2.4.1
print(pyproj.proj_version_str) # 6.2.1

## ESPG:3857, ESPG:4326
proj = pyproj.Transformer.from_crs(3826, 4326, always_xy=True)

x1, y1 = (310951.84060, 2.775913e+06)
x2, y2 = proj.transform(x1, y1)
print((x2, y2))  # (-105.15027111593008, 39.72785727727918)
# Out:
# 2.6.1.post1
# 6.2.1
# (121.60427737425519, 25.090275486930132)

# %% [markdown]
# ## Make mapping

# %%
## EPSG:3826
data = gpd.read_file("../tbl/Taipei_CODE_mapping/G97_63000_U0200_2015.shp")
## Get gemotry's lon, lat
data = data.to_crs("EPSG:4326")
data.head()
# Out:
#    U_ID       CODEBASE         CODE1     CODE2   TOWN_ID TOWN COUNTY_ID  \
# 0  1972  A6310-0024-00  A6310-01-006  A6310-01  63000100  內湖區     63000
# 1  1973  A6311-0791-00  A6311-61-005  A6311-61  63000110  士林區     63000
# 2  1974  A6311-0787-00  A6311-67-002  A6311-67  63000110  士林區     63000
# 3  1975  A6311-0793-00  A6311-62-004  A6311-62  63000110  士林區     63000
# 4  1976  A6311-0807-00  A6311-67-008  A6311-67  63000110  士林區     63000
#
#   COUNTY             X             Y          AREA  \
# 0    臺北市  310951.84060  2.775913e+06  362112.90727
# 1    臺北市  300103.56005  2.776286e+06   17541.31869
# 2    臺北市  302742.35826  2.776312e+06    3627.65319
# 3    臺北市  302298.08171  2.776278e+06   15430.37397
# 4    臺北市  302823.86029  2.776199e+06   52775.40011
#
#                                             geometry
# 0  POLYGON Z ((121.60048 25.09029 0.00000, 121.60...
# 1  POLYGON Z ((121.49558 25.09445 0.00000, 121.49...
# 2  POLYGON Z ((121.52301 25.09467 0.00000, 121.52...
# 3  POLYGON Z ((121.51889 25.09466 0.00000, 121.51...
# 4  POLYGON Z ((121.52266 25.09459 0.00000, 121.52...

# %% [markdown]
# # Bus stop

# %%
bus_stop = gpd.read_file("../data/busstop/busstop.shp")

# %%
bus_stop['lon'] = bus_stop['geometry'].map(lambda x: x.x)
bus_stop['lat'] = bus_stop['geometry'].map(lambda x: x.y)

# %%
bus_stop.drop(columns=['geometry']).to_csv('../data/busstop.csv')

# %%
bus_nums = []
for key, geom in tqdm(data['geometry'].items()):
    tmp_nums = np.sum(bus_stop.within(geom))
    bus_nums.append(tmp_nums)
# Out:
# 11490it [01:03, 179.54it/s]

# %%
data['bus_stops'] = bus_nums

# %% [markdown]
# # MRT

# %%
MRT_info = pd.read_csv('../data/MRT_station_lonlat.csv', encoding='big5')
MRT_lonlat = [Point(float(x['經度']), float(x['緯度'])) for index, x in MRT_info.iterrows()]
MRT_lonlat = gpd.GeoDataFrame(geometry=MRT_lonlat)

# %%
pd.set_option('display.max_rows', 10)
chinese = '[\u4e00-\u9fa5]+'
MRT_names = MRT_info['出入口名稱'].map(lambda x: ''.join(re.findall(chinese, x)))

# %%
MRT_nums = []
for key, geom in tqdm(data['geometry'].items()):
    #tmp_nums = np.sum(MRT_lonlat.within(geom))
    tmp_nums = MRT_lonlat.within(geom)
    tmp_nums = pd.DataFrame(tmp_nums)
    tmp_nums['station'] = MRT_names
    tmp_nums = tmp_nums.groupby('station')[0].sum()
    tmp_nums = tmp_nums.mask(tmp_nums >= 1, 1).sum()
    MRT_nums.append(tmp_nums)
# Out:
# 6155it [00:10, 580.61it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [44], in <cell line: 2>()
#       6 tmp_nums['station'] = MRT_names
#       7 tmp_nums = tmp_nums.groupby('station')[0].sum()
# ----> 8 tmp_nums = tmp_nums.mask(tmp_nums >= 1, 1).sum()
#       9 MRT_nums.append(tmp_nums)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/series.py:5584, in Series.mask(self, cond, other, inplace, axis, level, errors, try_cast)
#    5571 @deprecate_nonkeyword_arguments(
#    5572     version=None, allowed_args=["self", "cond", "other"]
#    5573 )
#    (...)
#    5582     try_cast=lib.no_default,
#    5583 ):
# -> 5584     return super().mask(cond, other, inplace, axis, level, errors, try_cast)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/generic.py:9344, in NDFrame.mask(self, cond, other, inplace, axis, level, errors, try_cast)
#    9341 if not hasattr(cond, "__invert__"):
#    9342     cond = np.array(cond)
# -> 9344 return self.where(
#    9345     ~cond,
#    9346     other=other,
#    9347     inplace=inplace,
#    9348     axis=axis,
#    9349     level=level,
#    9350     errors=errors,
#    9351 )
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/series.py:5569, in Series.where(self, cond, other, inplace, axis, level, errors, try_cast)
#    5556 @deprecate_nonkeyword_arguments(
#    5557     version=None, allowed_args=["self", "cond", "other"]
#    5558 )
#    (...)
#    5567     try_cast=lib.no_default,
#    5568 ):
# -> 5569     return super().where(cond, other, inplace, axis, level, errors, try_cast)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/generic.py:9308, in NDFrame.where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9300 if try_cast is not lib.no_default:
#    9301     warnings.warn(
#    9302         "try_cast keyword is deprecated and will be removed in a "
#    9303         "future version.",
#    9304         FutureWarning,
#    9305         stacklevel=find_stack_level(),
#    9306     )
# -> 9308 return self._where(cond, other, inplace, axis, level, errors=errors)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/generic.py:9075, in NDFrame._where(self, cond, other, inplace, axis, level, errors)
#    9072     cond = cond.astype(bool)
#    9074 cond = -cond if inplace else cond
# -> 9075 cond = cond.reindex(self._info_axis, axis=self._info_axis_number, copy=False)
#    9077 # try to align with other
#    9078 if isinstance(other, NDFrame):
#    9079
#    9080     # align with me
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/series.py:4672, in Series.reindex(self, *args, **kwargs)
#    4668         raise TypeError(
#    4669             "'index' passed as both positional and keyword argument"
#    4670         )
#    4671     kwargs.update({"index": index})
# -> 4672 return super().reindex(**kwargs)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/generic.py:4952, in NDFrame.reindex(self, *args, **kwargs)
#    4948 self._consolidate_inplace()
#    4950 # if all axes that are requested to reindex are equal, then only copy
#    4951 # if indicated must have index names equal here as well as values
# -> 4952 if all(
#    4953     self._get_axis(axis).identical(ax)
#    4954     for axis, ax in axes.items()
#    4955     if ax is not None
#    4956 ):
#    4957     if copy:
#    4958         return self.copy()
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/generic.py:4953, in <genexpr>(.0)
#    4948 self._consolidate_inplace()
#    4950 # if all axes that are requested to reindex are equal, then only copy
#    4951 # if indicated must have index names equal here as well as values
#    4952 if all(
# -> 4953     self._get_axis(axis).identical(ax)
#    4954     for axis, ax in axes.items()
#    4955     if ax is not None
#    4956 ):
#    4957     if copy:
#    4958         return self.copy()
#
# KeyboardInterrupt:

# %%
MRT_nums
# Out:
# [0, 0]

# %%
data['MRT_stops'] = MRT_nums

# %%
data = data.drop(columns=['geometry'])

# %%
## ESPG:3857, ESPG:4326
proj = pyproj.Transformer.from_crs(3826, 4326, always_xy=True)

lons = []
lats = []
for index, x in data.iterrows():
    lon, lat = proj.transform(x['X'], x['Y'])
    
    lons.append(lon)
    lats.append(lat)

# %%
data['lon'] = lons
data['lat'] = lats
data
# Out:
#        U_ID       CODEBASE         CODE1     CODE2   TOWN_ID TOWN COUNTY_ID  \
# 0      1972  A6310-0024-00  A6310-01-006  A6310-01  63000100  內湖區     63000
# 1      1973  A6311-0791-00  A6311-61-005  A6311-61  63000110  士林區     63000
# 2      1974  A6311-0787-00  A6311-67-002  A6311-67  63000110  士林區     63000
# 3      1975  A6311-0793-00  A6311-62-004  A6311-62  63000110  士林區     63000
# 4      1976  A6311-0807-00  A6311-67-008  A6311-67  63000110  士林區     63000
# ...     ...            ...           ...       ...       ...  ...       ...
# 11485  5719  A6304-0927-00  A6304-62-009  A6304-62  63000040  中山區     63000
# 11486  5720  A6306-0496-00  A6306-44-003  A6306-44  63000060  大同區     63000
# 11487  5721  A6301-0457-00  A6301-44-005  A6301-44  63000010  松山區     63000
# 11488  5722  A6301-0458-00  A6301-43-007  A6301-43  63000010  松山區     63000
# 11489  5723  A6301-0506-00  A6301-05-003  A6301-05  63000010  松山區     63000
#
#       COUNTY             X             Y          AREA  bus_stops  MRT_stop  \
# 0        臺北市  310951.84060  2.775913e+06  362112.90727          0         0
# 1        臺北市  300103.56005  2.776286e+06   17541.31869          1         0
# 2        臺北市  302742.35826  2.776312e+06    3627.65319          1         0
# 3        臺北市  302298.08171  2.776278e+06   15430.37397          0         0
# 4        臺北市  302823.86029  2.776199e+06   52775.40011          1         0
# ...      ...           ...           ...           ...        ...       ...
# 11485    臺北市  302781.13917  2.771747e+06    4981.14640          0         0
# 11486    臺北市  301528.18724  2.771701e+06    6921.59065          1         0
# 11487    臺北市  306365.70545  2.771756e+06    3357.22049          0         0
# 11488    臺北市  305681.16687  2.771755e+06    3858.13019          0         0
# 11489    臺北市  308046.25160  2.771638e+06   96818.73401          0         0
#
#               lon        lat
# 0      121.604277  25.090279
# 1      121.496745  25.094041
# 2      121.522907  25.094185
# 3      121.518501  25.093893
# 4      121.523710  25.093165
# ...           ...        ...
# 11485  121.523116  25.052972
# 11486  121.510697  25.052598
# 11487  121.558642  25.052921
# 11488  121.551858  25.052938
# 11489  121.575292  25.051796
#
# [11490 rows x 15 columns]

# %%
data.to_csv('../tbl/Taipei_mapping.csv', index=None)
