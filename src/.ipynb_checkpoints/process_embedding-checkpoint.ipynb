# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/109_combine.csv')

# %%
#不含車位_各屋齡合計棟數
#不含車位_各屋齡合計面積
#不含車位_各屋齡整體中位數房價
#不含車位_店面(店舖)棟數
#不含車位_店面(店舖)面積
#不含車位_辦公商業大樓棟數
#不含車位_辦公商業大樓面積
#不含車位_店面(店舖)中位數房價
#不含車位_辦公商業大樓中位數房價


data['house_price_per'] = data['不含車位_各屋齡整體中位數房價'] * data['不含車位_各屋齡合計棟數'] / (data['不含車位_各屋齡合計面積'] + 1e-7)
data['shop_price_per'] = data['不含車位_店面(店舖)中位數房價'] * data['不含車位_店面(店舖)棟數'] / (data['不含車位_店面(店舖)面積'] + 1e-7)
data['office_price_per'] = data['不含車位_辦公商業大樓中位數房價'] * data['不含車位_辦公商業大樓棟數'] / (data['不含車位_辦公商業大樓面積'] + 1e-7)
###

data['house_price_per'] = data['house_price_per'].replace(0, np.nan)
data['shop_price_per'] = data['shop_price_per'].replace(0, np.nan)
data['office_price_per'] = data['office_price_per'].replace(0, np.nan)

# %%
## TOWN, 二級發布區代碼, 一級發布區代碼	
test = 'TOWN'
mean_data = data.groupby(test).mean()
print(len(mean_data))
mean_data
# Out:
# 12
#          TOWN_ID              X             Y         lon        lat  \
# TOWN
# 中山區   63000040.0  304018.764420  2.772746e+06  121.535419  25.061865
# 中正區   63000050.0  302468.796685  2.769380e+06  121.519928  25.031527
# 信義區   63000020.0  307570.183533  2.769781e+06  121.570494  25.034960
# 內湖區   63000100.0  309704.291409  2.774329e+06  121.591838  25.075935
# 北投區   63000120.0  300899.358610  2.779882e+06  121.504765  25.126396
# 南港區   63000090.0  310647.206026  2.771217e+06  121.601048  25.047807
# 士林區   63000110.0  302834.688575  2.777154e+06  121.523853  25.101698
# 大同區   63000060.0  301884.157608  2.772791e+06  121.514263  25.062341
# 大安區   63000030.0  304808.546607  2.769274e+06  121.543108  25.030490
# 文山區   63000080.0  306146.955338  2.765182e+06  121.556204  24.993499
# 松山區   63000010.0  306296.071947  2.771904e+06  121.557955  25.054176
# 萬華區   63000070.0  300372.451496  2.769348e+06  121.499154  25.031307
#
#               AREA         人口數          人口密度   0-14歲人口數   15-64歲人口數  ...  \
# TOWN                                                                 ...
# 中山區   11600.187913  195.244987  44541.565606  24.759372  134.461203  ...
# 中正區    9760.670978  220.038462  51000.225242  37.685185  143.052707  ...
# 信義區   12409.775704  249.950058  57507.457933  30.599303  171.490128  ...
# 內湖區   26117.249993  247.709904  55775.654566  37.276074  177.939527  ...
# 北投區   49518.294688  231.118738  44236.542635  32.507421  159.795918  ...
# 南港區   45662.568344  272.610092  48121.630505  36.371560  193.885321  ...
# 士林區   48468.788328  229.241152  44692.039572  29.905350  157.477366  ...
# 大同區    8309.256537  233.000000  51180.512613  31.524436  159.695489  ...
# 大安區    8922.409598  245.622565  54934.802232  39.354708  156.878247  ...
# 文山區   29846.311272  276.148148  49899.445000  38.982510  193.522634  ...
# 松山區   10389.168467  254.147208  57317.831168  39.116751  166.585025  ...
# 萬華區    9753.061277  251.706447  60008.465926  27.289438  175.489712  ...
#
#       MIDDAY_WORK  AFTERNOON_WORK  EVENING_WORK  MORNING_WEEKEND  \
# TOWN
# 中山區    1227946.97      1219019.04    1120933.64        616316.14
# 中正區     902223.40       895413.81     861093.63        419579.20
# 信義區     699285.47       703489.59     668899.81        410262.42
# 內湖區     781412.78       754385.72     721408.50        502062.50
# 北投區     540547.56       532752.46     499448.25        437599.62
# 南港區     353446.44       347861.30     342036.21        239274.99
# 士林區     670775.71       688329.13     661448.70        534595.29
# 大同區     447197.46       460690.17     470477.60        284903.89
# 大安區    1180592.25      1193389.78    1124240.40        596488.20
# 文山區     461829.39       458132.66     484333.34        454376.23
# 松山區     703588.87       688431.01     634827.78        361013.08
# 萬華區     463662.07       490861.04     529077.34        424306.76
#
#       MIDDAY_WEEKEND  AFTERNOON_WEEKEND  EVENING_WEEKEND  house_price_per  \
# TOWN
# 中山區        962611.85          991624.89        855812.84    656811.383544
# 中正區        801455.08          851999.89        703209.61    731518.986370
# 信義區        638423.70          701300.63        597514.40    688914.035672
# 內湖區        628229.13          610269.61        523692.17    526558.364120
# 北投區        564035.14          548401.90        455205.34    468130.742233
# 南港區        317771.44          323709.46        274099.54    524115.984392
# 士林區        719896.18          726237.04        636598.56    562391.104465
# 大同區        452753.33          492620.61        431231.93    529302.684190
# 大安區        996480.53         1038302.46        891852.58    813979.598362
# 文山區        544622.79          512993.29        446438.70    475251.743998
# 松山區        511214.65          515887.31        464836.35    702383.837020
# 萬華區        560541.22          607057.01        560228.11    471957.830095
#
#       shop_price_per  office_price_per
# TOWN
# 中山區     9.908143e+05     600347.567977
# 中正區     8.889316e+05     738979.214173
# 信義區     1.044868e+06     732068.606038
# 內湖區     1.128632e+06     555301.285134
# 北投區     7.342271e+05     852071.000875
# 南港區     9.695379e+05     639255.513442
# 士林區     1.210185e+06     432319.617722
# 大同區     8.679053e+05     589789.608155
# 大安區     1.285412e+06     747312.010198
# 文山區     6.840696e+05               NaN
# 松山區     1.019966e+06     641763.220349
# 萬華區     6.965093e+05     446825.588522
#
# [12 rows x 40 columns]

# %%
## Get dictionary
if test == 'TOWN':
    dicts = dict([(i, i) for i in list(mean_data.index)])
else:
    dicts = data[[test, 'TOWN']].drop_duplicates([test]).set_index(test).to_dict()['TOWN']

#print(dicts)
town2idx = dict([(j, i) for i, j in enumerate(set(dicts.values()))])

# %%
mean_data = mean_data.drop(columns=['不含車位_各屋齡整體中位數房價', '不含車位_各屋齡合計棟數', '不含車位_各屋齡合計面積',
                                                                                      '不含車位_店面(店舖)中位數房價', '不含車位_店面(店舖)棟數', '不含車位_店面(店舖)面積',
                                                                                      '不含車位_辦公商業大樓中位數房價', '不含車位_辦公商業大樓棟數', '不含車位_辦公商業大樓面積'])

# %%
embedding = mean_data.iloc[:, 6:]
## min/max normalization
#embedding = (embedding - embedding.min()) / (embedding.max() - embedding.min())
## standardization
embedding = (embedding - embedding.mean()) / embedding.std()

## fill na
embedding = embedding.fillna(0)
## Test
embedding = embedding.apply(lambda x: x / np.sqrt(np.sum(x**2)), axis=1)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
scores = np.squeeze(cosine_similarity(embedding, embedding.loc[['內湖區']]))
index = np.argsort(scores)[::-1]

# %%
print(scores[index])
embedding.iloc[index]
# Out:
# [ 1.          0.38201418  0.20953635  0.19711004  0.12825203  0.05065611
#  -0.20123514 -0.20317009 -0.24934599 -0.35867844 -0.46827956 -0.56066562]
#            人口數      人口密度  0-14歲人口數  15-64歲人口數  65歲以上人口數    批發及零售業    住宿及餐飲業  \
# TOWN
# 內湖區   0.067368  0.207193  0.190826   0.183920 -0.510532 -0.125743 -0.306457
# 士林區  -0.165569 -0.357305 -0.220466  -0.132871 -0.037778 -0.280413 -0.215088
# 文山區   0.349738 -0.071053  0.238874   0.354204  0.045525 -0.311264 -0.292165
# 大安區   0.021312  0.084374  0.155185  -0.069684  0.176022  0.071180  0.182116
# 中山區  -0.284407 -0.173188 -0.243447  -0.236176 -0.163959  0.193555  0.210561
# 北投區  -0.123150 -0.331233 -0.063008  -0.083581 -0.172509 -0.361510 -0.304612
# 信義區   0.154895  0.478908 -0.283794   0.140094  0.437391  0.084218  0.059924
# 南港區   0.224079 -0.103912  0.085095   0.256674 -0.006739 -0.117200 -0.129792
# 中正區  -0.287043 -0.031525  0.225226  -0.366730 -0.175194  0.117785  0.225418
# 松山區   0.181325  0.351814  0.361219   0.013757  0.368699  0.233896  0.157304
# 萬華區   0.094334  0.338375 -0.287404   0.118902  0.260913  0.047698  0.072499
# 大同區  -0.083914 -0.015531 -0.091605  -0.069719 -0.029911  0.310062  0.120971
#
#       藝術、娛樂及休閒服務業  NIGHT_WORK  DAY_WORK(7:00~13:00)  ...  MIDDAY_WORK  \
# TOWN                                                 ...
# 內湖區     -0.223428    0.242392              0.260829  ...     0.076121
# 士林區     -0.238746    0.220792             -0.005259  ...    -0.032179
# 文山區     -0.308072    0.093453             -0.141062  ...    -0.195961
# 大安區      0.108328    0.204303              0.216605  ...     0.235698
# 中山區      0.171032    0.157797              0.216570  ...     0.251075
# 北投區     -0.345782    0.039975             -0.084906  ...    -0.142115
# 信義區      0.116780    0.024307              0.114633  ...    -0.005409
# 南港區     -0.140382   -0.255391             -0.182732  ...    -0.203233
# 中正區      0.175280   -0.202168              0.091326  ...     0.203888
# 松山區      0.265950   -0.148623             -0.022094  ...     0.001055
# 萬華區      0.304169   -0.153950             -0.261221  ...    -0.187480
# 大同區      0.035938   -0.311359             -0.275275  ...    -0.183742
#
#       AFTERNOON_WORK  EVENING_WORK  MORNING_WEEKEND  MIDDAY_WEEKEND  \
# TOWN
# 內湖區         0.050374      0.049375         0.149951       -0.018148
# 士林區        -0.014631     -0.017270         0.238211        0.111669
# 文山區        -0.200631     -0.177805         0.029115       -0.111412
# 大安區         0.244001      0.251128         0.192931        0.247494
# 中山區         0.248839      0.241596         0.210691        0.216985
# 北投區        -0.150197     -0.176479        -0.005403       -0.095972
# 信義區         0.001211     -0.013691        -0.117757       -0.006878
# 南港區        -0.208203     -0.221345        -0.292179       -0.266291
# 中正區         0.198537      0.214508        -0.052352        0.231067
# 松山區        -0.017289     -0.056859        -0.237073       -0.220871
# 萬華區        -0.167539     -0.131506        -0.030906       -0.089760
# 大同區        -0.175494     -0.168503        -0.279028       -0.191873
#
#       AFTERNOON_WEEKEND  EVENING_WEEKEND  house_price_per  shop_price_per  \
# TOWN
# 內湖區           -0.064029        -0.070433        -0.161784        0.236290
# 士林區            0.088747         0.105304        -0.081508        0.365306
# 文山區           -0.159132        -0.157947        -0.236704       -0.325485
# 大安區            0.248191         0.249263         0.259254        0.232581
# 中山區            0.210864         0.214529         0.070146        0.021290
# 北投區           -0.130146        -0.158084        -0.270039       -0.286918
# 信義區            0.086741         0.068129         0.354144        0.194173
# 南港區           -0.260347        -0.270473        -0.100761        0.007970
# 中正區            0.260972         0.213701         0.334012       -0.105404
# 松山區           -0.229964        -0.198183         0.307733        0.104086
# 萬華區           -0.055272        -0.012110        -0.234424       -0.299644
# 大同區           -0.160155        -0.156792        -0.115531       -0.096089
#
#       office_price_per
# TOWN
# 內湖區          -0.167435
# 士林區          -0.446411
# 文山區           0.000000
# 大安區           0.122448
# 中山區          -0.035497
# 北投區           0.419056
# 信義區           0.339415
# 南港區           0.006475
# 中正區           0.235021
# 松山區           0.019945
# 萬華區          -0.322475
# 大同區          -0.070062
#
# [12 rows x 25 columns]

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = [u'SimHei']
mpl.rcParams['axes.unicode_minus']=False

# %%
tsne_results = TSNE(n_components=2, learning_rate='auto', init='pca', random_state=10).fit_transform(embedding)
pca_results = PCA(n_components=2).fit_transform(embedding)
# Out:
# /home/jasonluo/anaconda3/envs/py38/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
colors = embedding.index.map(lambda x: town2idx[dicts[x]])

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10, 8))

sc = plt.scatter(pca_results[:, 0], pca_results[:, 1], alpha=0.8, s=30, c=colors)#, cmap='rainbow')
for index, pt in enumerate(pca_results):
    plt.text(pt[0], pt[1], list(embedding.index)[index])
    
plt.legend(sc.legend_elements()[0], town2idx.keys(), title="DISTRICT")
plt.show()

# %%
#
